# %%
import pandas as pd
import numpy as np
df = pd.read_csv("videosUS.csv")

# %%
#Showing the first 5 lines of df
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0         22.0  2017-11-13T17:13:01.000Z
# 1         24.0  2017-11-13T07:30:00.000Z
# 2         23.0  2017-11-12T19:05:24.000Z
# 3         24.0  2017-11-13T11:00:04.000Z
# 4         24.0  2017-11-12T18:01:41.000Z
#
# ...

# %%
#Shoing the missing data:
df.isna()
# Out:
#        video_id  trending_date  title  channel_title  category_id  \
# 0         False          False  False          False        False
# 1         False          False  False          False        False
# 2         False          False  False          False        False
# 3         False          False  False          False        False
# 4         False          False  False          False        False
# ...         ...            ...    ...            ...          ...
# 41410     False          False  False          False        False
# 41411     False          False  False          False        False
# 41412     False          False  False          False        False
# 41413     False          False  False          False        False
# 41414     False          False  False          False        False
#
#        publish_time   tags  views  likes  dislikes  comment_count  \
# 0             False  False  False  False     False          False
# ...

# %%
#How many missin values :
df.isna().sum()
# Out:
# video_id                     0
# trending_date              466
# title                      466
# channel_title              466
# category_id                466
# publish_time               466
# tags                       466
# views                      466
# likes                      466
# dislikes                   466
# comment_count              466
# thumbnail_link             466
# comments_disabled          466
# ratings_disabled           466
# video_error_or_removed     466
# description               1036
# dtype: int64

# %%
#in which column ?
df.loc[:, df.isnull().any()].columns
# Out:
# Index(['trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df.isna().sum()/(len(df))*100
# Out:
# video_id                  0.000000
# trending_date             1.125196
# title                     1.125196
# channel_title             1.125196
# category_id               1.125196
# publish_time              1.125196
# tags                      1.125196
# views                     1.125196
# likes                     1.125196
# dislikes                  1.125196
# comment_count             1.125196
# thumbnail_link            1.125196
# comments_disabled         1.125196
# ratings_disabled          1.125196
# video_error_or_removed    1.125196
# description               2.501509
# dtype: float64

# %% [markdown]
# # Assumption for lissing data :

# %% [raw]
# As we can see, the data missing represente 18% from our data, so we can simply delete them without having a problem of losing a lot of information

# %%
#Listwise deletion
df.dropna(inplace=True)
df.isna().sum()/(len(df))*100
# Out:
# video_id                  0.0
# trending_date             0.0
# title                     0.0
# channel_title             0.0
# category_id               0.0
# publish_time              0.0
# tags                      0.0
# views                     0.0
# likes                     0.0
# dislikes                  0.0
# comment_count             0.0
# thumbnail_link            0.0
# comments_disabled         0.0
# ratings_disabled          0.0
# video_error_or_removed    0.0
# description               0.0
# dtype: float64

# %%
#Mean,median,quartiles of each numerical values
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
#spoting the outliers
df_zscore = (df - df.mean())/df.std()
df=df[df_zscore>3]
df
# Out:
#       video_id trending_date title channel_title  category_id publish_time  \
# 0          NaN           NaN   NaN           NaN          NaN          NaN
# 1          NaN           NaN   NaN           NaN          NaN          NaN
# 2          NaN           NaN   NaN           NaN          NaN          NaN
# 3          NaN           NaN   NaN           NaN          NaN          NaN
# 4          NaN           NaN   NaN           NaN          NaN          NaN
# ...        ...           ...   ...           ...          ...          ...
# 41410      NaN           NaN   NaN           NaN          NaN          NaN
# 41411      NaN           NaN   NaN           NaN          NaN          NaN
# 41412      NaN           NaN   NaN           NaN          NaN          NaN
# 41413      NaN           NaN   NaN           NaN          NaN          NaN
# 41414      NaN           NaN   NaN           NaN          NaN          NaN
#
#       tags  views  likes  dislikes  comment_count thumbnail_link  \
# ...

# %% [raw]
# We have 10 categories

# %% [raw]
# Yes, because almost the machine learning algorithms accept only numerical values, and in our case we have some varibles that's not numerical such as "Title" or "Tags"

# %%
y = pd.get_dummies(df.tags, prefix='tags')
y
# Out:
#        tags_#MeToo|"Grammys 2018"|"Janelle Monáe"|"Kesha"  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 41410                                                  0
# 41411                                                  0
# 41412                                                  0
# 41413                                                  0
# 41414                                                  0
#
#        tags_#NeighborDanceChallenge|"#neighbor"|"#dance"|"#loveyourneighbors"|"#dreamer"|"#dancing"|"#musicvideo"|"#love"|"#iphone8"|"#iMovie"|"#iTunes"  \
# 0                                                      0
# 1                                                      0
# ...

# %%
#Number of tags
df.isna().sum()
#The is 466 tags
# Out:
# video_id                     0
# trending_date              466
# title                      466
# channel_title              466
# category_id                466
# publish_time               466
# tags                       466
# views                      466
# likes                      466
# dislikes                   466
# comment_count              466
# thumbnail_link             466
# comments_disabled          466
# ratings_disabled           466
# video_error_or_removed     466
# description               1036
# dtype: int64

# %%
#Most common Tags:
df["tags"].value_counts().idxmax()
# Out:
# '[none]'
